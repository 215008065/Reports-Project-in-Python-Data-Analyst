# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r"C:\Users\USER 01\Documents\Bearing.xlsx")

# %%
data.head()
# Out:
#        MONTH            1            2            3            4            5  \
# 0 2020-01-01  37212380.78  39375354.05  40929824.04  42598840.59  41685974.04
# 1 2020-02-01  38471376.20  38475176.20  40825235.10  42337607.98  43308487.95
# 2 2020-03-01  36103711.37  39580950.81  41882757.48  43167638.50  44102980.16
# 3 2020-04-01  37491950.18  38617596.85  39509133.49  39921453.49  39921453.49
# 4 2020-05-01  32356998.48  33088151.81  33088151.81  33106301.81  35366823.06
#
#              6            7            8            9  ...           22  \
# 0  43196060.73  44146175.74  45072635.74  45881995.74  ...  45026122.40
# 1  44132670.93  45138411.21  45467644.55  45521291.21  ...  44792579.43
# 2  45037046.65  45530812.48  45530812.48  46258005.82  ...  43203755.72
# 3  40569340.17  41115875.20  41582971.86  42089870.15  ...  39219460.09
# 4  36849133.06  37841386.09  38689124.39  39009675.88  ...  33746659.98
#
# ...

# %%
data_t=data.transpose()

# %%
data_t.head(1)
# Out:
#                         0                    1                    2   \
# MONTH  2020-01-01 00:00:00  2020-02-01 00:00:00  2020-03-01 00:00:00
#
#                         3                    4                    5   \
# MONTH  2020-04-01 00:00:00  2020-05-01 00:00:00  2020-06-01 00:00:00
#
#                         6                    7                    8   \
# MONTH  2020-07-01 00:00:00  2020-08-01 00:00:00  2020-09-01 00:00:00
#
#                         9                    10                   11
# MONTH  2020-10-01 00:00:00  2020-11-01 00:00:00  2020-12-01 00:00:00

# %%
data_t.drop("MONTH", inplace=True)

# %%
data_t.head()
# Out:
#             0            1            2            3            4   \
# 1  37212380.78   38471376.2  36103711.37  37491950.18  32356998.48
# 2  39375354.05   38475176.2  39580950.81  38617596.85  33088151.81
# 3  40929824.04   40825235.1  41882757.48  39509133.49  33088151.81
# 4  42598840.59  42337607.98   43167638.5  39921453.49  33106301.81
# 5  41685974.04  43308487.95  44102980.16  39921453.49  35366823.06
#
#             5            6            7            8            9   \
# 1  35561030.22  36245617.89  38328943.17  39297333.76   38996025.8
# 2  36972133.54  37960657.67  38328943.17  40876273.75  41200217.46
# 3  38012774.01  39532781.04  40296723.14  42059838.73  42107882.46
# 4   38816570.6  40128931.04  41630213.14  43247581.26  42107882.46
# 5   39575803.9  40128931.04  42620376.45  43784056.26  43445332.47
#
#             10           11
# 1  38111938.67  37259686.65
# 2  40469005.34  39354225.21
# 3  41825915.11  40767461.89
# 4  42840505.12  42057256.89
# ...

# %%
data_t.rename(columns={0:"Jan_20",1:"Feb_20",2:"March_20",3:"Apr_20",4:"May_20",5:"June_20",6:"July_20",
                      7:"Aug_20", 8:"Sept_20",9:"Oct_20",10:"Nov_20",11:"Dec_20"}, inplace=True)

# %%
data_t.head()
# Out:
#         Jan_20       Feb_20     March_20       Apr_20       May_20  \
# 1  37212380.78   38471376.2  36103711.37  37491950.18  32356998.48
# 2  39375354.05   38475176.2  39580950.81  38617596.85  33088151.81
# 3  40929824.04   40825235.1  41882757.48  39509133.49  33088151.81
# 4  42598840.59  42337607.98   43167638.5  39921453.49  33106301.81
# 5  41685974.04  43308487.95  44102980.16  39921453.49  35366823.06
#
#        June_20      July_20       Aug_20      Sept_20       Oct_20  \
# 1  35561030.22  36245617.89  38328943.17  39297333.76   38996025.8
# 2  36972133.54  37960657.67  38328943.17  40876273.75  41200217.46
# 3  38012774.01  39532781.04  40296723.14  42059838.73  42107882.46
# 4   38816570.6  40128931.04  41630213.14  43247581.26  42107882.46
# 5   39575803.9  40128931.04  42620376.45  43784056.26  43445332.47
#
#         Nov_20       Dec_20
# 1  38111938.67  37259686.65
# 2  40469005.34  39354225.21
# 3  41825915.11  40767461.89
# 4  42840505.12  42057256.89
# ...

# %%
data_t.isnull().sum()
# Out:
# Jan_20      0
# Feb_20      2
# March_20    0
# Apr_20      1
# May_20      0
# June_20     1
# July_20     0
# Aug_20      0
# Sept_20     1
# Oct_20      0
# Nov_20      1
# Dec_20      0
# dtype: int64

# %%
data_t.fillna(0, inplace=True)

# %%
data_t.isnull().sum()
# Out:
# Jan_20      0
# Feb_20      0
# March_20    0
# Apr_20      0
# May_20      0
# June_20     0
# July_20     0
# Aug_20      0
# Sept_20     0
# Oct_20      0
# Nov_20      0
# Dec_20      0
# dtype: int64

# %%
data_t.head(1)
# Out:
#         Jan_20      Feb_20     March_20       Apr_20       May_20  \
# 1  37212380.78  38471376.2  36103711.37  37491950.18  32356998.48
#
#        June_20      July_20       Aug_20      Sept_20      Oct_20  \
# 1  35561030.22  36245617.89  38328943.17  39297333.76  38996025.8
#
#         Nov_20       Dec_20
# 1  38111938.67  37259686.65

# %%
data_t.rename_axis("date", inplace=True)

# %%
data_r=data_t.reset_index()

# %%
data.plot?

# %%
plt.plot(data_r.date, data_r["Jan_20"], label="Jan_20")
plt.plot(data_r.date, data_r["Feb_20"], label="Feb_20" )
plt.plot(data_r.date, data_r["March_20"], label="March_20")
plt.plot(data_r.date, data_r["Apr_20"], label="Apr_20")
plt.plot(data_r.date, data_r["May_20"], label="May_20")
plt.plot(data_r.date, data_r["June_20"], label="June_20")
plt.plot(data_r.date, data_r["July_20"], label="July_20")
plt.plot(data_r.date, data_r["Aug_20"], label="Aug_20")
plt.plot(data_r.date, data_r["Sept_20"], label="Sept_20")
plt.plot(data_r.date, data_r["Oct_20"], label="Oct_20")
plt.plot(data_r.date, data_r["Nov_20"], label="Nov_20")
plt.plot(data_r.date, data_r["Dec_20"], label="Dec_20")
plt.legend(loc=0)
plt.legend?

# %%
data_r.head()
# Out:
#    date       Jan_20       Feb_20     March_20       Apr_20       May_20  \
# 0     1  37212380.78  38471376.20  36103711.37  37491950.18  32356998.48
# 1     2  39375354.05  38475176.20  39580950.81  38617596.85  33088151.81
# 2     3  40929824.04  40825235.10  41882757.48  39509133.49  33088151.81
# 3     4  42598840.59  42337607.98  43167638.50  39921453.49  33106301.81
# 4     5  41685974.04  43308487.95  44102980.16  39921453.49  35366823.06
#
#        June_20      July_20       Aug_20      Sept_20       Oct_20  \
# 0  35561030.22  36245617.89  38328943.17  39297333.76  38996025.80
# 1  36972133.54  37960657.67  38328943.17  40876273.75  41200217.46
# 2  38012774.01  39532781.04  40296723.14  42059838.73  42107882.46
# 3  38816570.60  40128931.04  41630213.14  43247581.26  42107882.46
# 4  39575803.90  40128931.04  42620376.45  43784056.26  43445332.47
#
#         Nov_20       Dec_20
# 0  38111938.67  37259686.65
# 1  40469005.34  39354225.21
# 2  41825915.11  40767461.89
# ...

# %%
data_r.corr()
# Out:
#               date    Jan_20    Feb_20  March_20    Apr_20    May_20  \
# date      1.000000 -0.023190 -0.440871 -0.184920 -0.497046 -0.094279
# Jan_20   -0.023190  1.000000  0.511288  0.940196  0.594238  0.872433
# Feb_20   -0.440871  0.511288  1.000000  0.626950  0.818475  0.504660
# March_20 -0.184920  0.940196  0.626950  1.000000  0.683426  0.868860
# Apr_20   -0.497046  0.594238  0.818475  0.683426  1.000000  0.479802
# May_20   -0.094279  0.872433  0.504660  0.868860  0.479802  1.000000
# June_20  -0.360762  0.543023  0.788351  0.645208  0.967053  0.417973
# July_20  -0.088546  0.980472  0.476944  0.927335  0.607676  0.859702
# Aug_20   -0.219533  0.942504  0.588920  0.968419  0.656706  0.868394
# Sept_20  -0.405285  0.515352  0.790377  0.628813  0.962096  0.392859
# Oct_20   -0.337618  0.844749  0.678791  0.863464  0.627927  0.871597
# Nov_20   -0.414117  0.614266  0.833354  0.729368  0.984715  0.508410
# Dec_20   -0.125922 -0.090562 -0.154053 -0.018599 -0.018623 -0.098826
#
# ...

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(data_r.corr(),  linewidths=0.5, annot=True, cmap="YlGnBu",)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap?

# %%
#plt.bar( data_r["Jan_20"], data_r.sum(axis="Jan_20"))

# %%
#example1-investigating the distribution of Revenue
x = data_r['Feb_20'].values
#creating the distribution of our revenue
sns.distplot(x, color='g')
# Out:
# C:\Users\USER 01\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
data_TR=data_r.transpose()

# %%
data_TR.head()
# Out:
#                    0            1            2            3            4   \
# date             1.00         2.00         3.00         4.00         5.00
# Jan_20    37212380.78  39375354.05  40929824.04  42598840.59  41685974.04
# Feb_20    38471376.20  38475176.20  40825235.10  42337607.98  43308487.95
# March_20  36103711.37  39580950.81  41882757.48  43167638.50  44102980.16
# Apr_20    37491950.18  38617596.85  39509133.49  39921453.49  39921453.49
#
#                    5            6            7            8            9   \
# date             6.00         7.00         8.00         9.00        10.00
# Jan_20    43196060.73  44146175.74  45072635.74  45881995.74  46807725.78
# Feb_20    44132670.93  45138411.21  45467644.55  45521291.21  46026561.17
# March_20  45037046.65  45530812.48  45530812.48  46258005.82  46821989.17
# Apr_20    40569340.17  41115875.20  41582971.86  42089870.15  42089870.15
#
#           ...           21           22           23           24  \
# ...

# %%
data_TR.drop("date", inplace=True)

# %%
data_TR.rename_axis("Months", inplace=True)

# %%
data_TR.sum(axis=1)
# Out:
# Months
# Jan_20      1.373038e+09
# Feb_20      1.274115e+09
# March_20    1.371627e+09
# Apr_20      1.184778e+09
# May_20      1.146456e+09
# June_20     1.187887e+09
# July_20     1.284185e+09
# Aug_20      1.331420e+09
# Sept_20     1.299539e+09
# Oct_20      1.352858e+09
# Nov_20      1.301036e+09
# Dec_20      1.258466e+09
# dtype: float64

# %%
#plt.bar(data_TR.sum(axis=1, )
